# %% [markdown]
# # 02 — Model Training & Evaluation
# Train RF, XGBoost, LightGBM — compare results.

# %%
import sys
sys.path.append('..')
from src.models.train import run_training, load_training_data
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd

# %%
X, y = load_training_data()
print('Class distribution:')
print(y.value_counts())

# %%
models = run_training()
print('Training complete!')

# %%
# Feature importance from Random Forest
import joblib
import numpy as np
FEATURES = ['Elevation','Slope','Aspect','TWI','NDVI','NDWI','Rainfall','Soil','LST']
rf = joblib.load('../outputs/models/random_forest.joblib')
importance = pd.Series(rf.feature_importances_, index=FEATURES).sort_values(ascending=True)
importance.plot(kind='barh', figsize=(8, 5), title='Feature Importance — Random Forest')
plt.tight_layout()
plt.savefig('../outputs/figures/feature_importance.png', dpi=200)
plt.show()
